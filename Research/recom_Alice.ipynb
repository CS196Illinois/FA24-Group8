# %%
import json
import requests
from bs4 import BeautifulSoup, Comment
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from collections import Counter
from gensim.test.utils import common_texts
from gensim.models.doc2vec import Doc2Vec, TaggedDocument

# %%
data = []
for i in range(0, 9):
    url = "https://researchops.web.illinois.edu/?page=" + str(i)
    response = requests.get(url)
    if response.status_code == 200:
        soup = BeautifulSoup(response.content, 'html.parser')  # Parse HTML content of the page

        table_rows = soup.find_all('tr')  # Find all table rows if the data is in a table

        for row in table_rows:
            columns = row.find_all('td')
            row_data = [column.text.strip() for column in columns]
            if row_data:  # Avoid appending empty rows
                data.append(row_data)

research_opps_w_duplicates = pd.DataFrame(data, columns=["Description", "Research Area", "Opportunity Timing", "Deadline Date"])
#find most common words
research_opps = research_opps_w_duplicates.drop_duplicates()
research_opps
# Out:
#                                            Description  \
# 0    Watershed Management Research and Outreach Und...
# 1    PINNACLE - Renewables and Cybersecurity for th...
# 2    Dryland Sustainability Research (IRES)This Int...
# 3    Injury Prevention Center Summer InternshipsThe...
# 4    MindCORE Summer Fellowship Program at UPennThi...
# ..                                                 ...
# 220  Congressional Hispanic Caucus Insititute (CHCI...
# 221  Molecular Biology and Genetics of Cell Signali...
# 222  Northwestern University Minority Health and He...
# 223  MEMOs Internship SchemeThe MEMOs Internship Sc...
# 224  Illinois Computer Science Summer Research Prog...
#
#                                          Research Area  \
# 0    Agriculture & Food Sciences, Natural Sciences,...
# 1                                 Science & Technology
# 2    Agriculture & Food Sciences, Humanities & Arts...
# 3                                    Medicine & Health
# 4        Medicine & Health, Social Sciences & Behavior
# ..                                                 ...
# 220                         Social Sciences & Behavior
# 221                                  Medicine & Health
# 222                                  Medicine & Health
# 223                                  Humanities & Arts
# 224                               Science & Technology
#
#                Opportunity Timing         Deadline Date
# 0                          Summer   Anticipated 12/8/24
# 1                          Summer              12/15/24
# 2                          Summer              12/15/24
# 3                          Summer  Anticipated 12/17/24
# 4                          Summer  Anticipated 12/31/24
# ..                            ...                   ...
# 220                  Fall, Summer   Anticipated 12/1/25
# 221                        Summer   Anticipated 1/31/26
# 222                        Summer               Rolling
# 223  Fall, Spring, Summer, Winter               Rolling
# 224                        Spring               Rolling
#
# [210 rows x 4 columns]

# %%
research_opps.to_csv("research_opps.csv")
