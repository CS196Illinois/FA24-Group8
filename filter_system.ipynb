# %%
import json
import requests
from bs4 import BeautifulSoup, Comment
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from collections import Counter
from gensim.test.utils import common_texts
from concurrent.futures import ThreadPoolExecutor

# %%
data = []
base_url = "https://researchops.web.illinois.edu"

# Scape Main Page
def scrape_main_page(page_num):
    url = base_url + "/?page=" + str(page_num)
    response = requests.get(url)
    if response.status_code == 200:
        soup = BeautifulSoup(response.content, 'html.parser')
        table_rows = soup.find_all('tr')
        for row in table_rows:
            first_td = row.find('td', headers="view-title-table-column")
            if first_td:
                topic_element = first_td.find('a')
                topic = topic_element.text.strip() if topic_element else None
                detail_url = base_url + topic_element['href'] if topic_element else None  # 詳細頁面 URL
                description = first_td.text.strip().replace(topic, "").strip() if topic else None

                columns = row.find_all('td')[1:]
                other_data = [column.text.strip() for column in columns]
                
                row_data = [topic, description, detail_url] + other_data
                data.append(row_data)


for i in range(0, 9):  
    scrape_main_page(i)

columns = ["Topic", "Description", "Detail URL", "Research Area", "Opportunity Timing", "Deadline Date"]
research_opps = pd.DataFrame(data, columns=columns)

full_data = []

# sraping webpage
def scrape_detail_page(row):
    detail_url = row['Detail URL']
    detail_response = requests.get(detail_url)
    if detail_response.status_code == 200:
        detail_soup = BeautifulSoup(detail_response.content, 'html.parser')

        # extract details like sponsoring_institution, location, etc.
        def extract_field(label):
            """根據標籤名稱提取對應數據"""
            label_div = detail_soup.find('div', class_="field__label", string=label)
            if label_div:
                value_div = label_div.find_next_sibling('div', class_="field__item")
                return value_div.text.strip() if value_div else None
            return None

        sponsoring_institution = extract_field("Sponsoring Institution")
        location = extract_field("Location")
        duration = extract_field("Duration")
        compensation = extract_field("Compensation")
        citizenship_requirement = extract_field("Citizenship Requirement")

        # Combine details of research opportunities
        full_data.append({
            "Topic": row["Topic"],
            "Description": row["Description"],
            "Detail URL": detail_url,
            "Research Area": row["Research Area"],
            "Opportunity Timing": row["Opportunity Timing"],
            "Deadline Date": row["Deadline Date"],
            "Sponsoring Institution": sponsoring_institution,
            "Location": location,
            "Duration": duration,
            "Compensation": compensation,
            "Citizenship Requirement": citizenship_requirement,
        })

with ThreadPoolExecutor(max_workers=5) as executor:
    executor.map(scrape_detail_page, [row for _, row in research_opps.iterrows()])

# to DataFrame
final_df = pd.DataFrame(full_data)
final_df.to_csv("research_opportunities_full.csv", index=False)

# %%
filter_data = pd.read_csv("research_opportunities_full.csv")
filter_data
# Out:
#                                                  Topic  \
# 0    Watershed Management Research and Outreach Und...
# 1               Dryland Sustainability Research (IRES)
# 2          MindCORE Summer Fellowship Program at UPenn
# 3    PINNACLE - Renewables and Cybersecurity for th...
# 4          Injury Prevention Center Summer Internships
# ..                                                 ...
# 220    Congressional Hispanic Caucus Insititute (CHCI)
# 221  Northwestern University Minority Health and He...
# 222  Molecular Biology and Genetics of Cell Signali...
# 223  Illinois Computer Science Summer Research Prog...
# 224                            MEMOs Internship Scheme
#
#                                            Description  \
# 0    This program will provide students with broade...
# 1    This International Research Experiences for St...
# 2    This fellowship provides students with a 10-we...
# 3    In this eight-week program, students will gain...
# 4    The internships are designed for students inte...
# ..                                                 ...
# 220  CIP provides Latino undergraduates of all majo...
# 221  The T37  provides health disparities research ...
# 222  The Summer Research Experience for Undergradua...
# 223  In the , students work with Illinois faculty m...
# 224  The  is a digital placement aimed at undergrad...
#
#                                             Detail URL  \
# 0    https://researchops.web.illinois.edu/opportuni...
# 1    https://researchops.web.illinois.edu/opportuni...
# 2    https://researchops.web.illinois.edu/opportuni...
# 3    https://researchops.web.illinois.edu/opportuni...
# 4    https://researchops.web.illinois.edu/opportuni...
# ..                                                 ...
# 220  https://researchops.web.illinois.edu/opportuni...
# 221  https://researchops.web.illinois.edu/opportuni...
# 222  https://researchops.web.illinois.edu/opportuni...
# 223  https://researchops.web.illinois.edu/opportuni...
# 224  https://researchops.web.illinois.edu/opportuni...
#
#                                          Research Area  \
# 0    Agriculture & Food Sciences, Natural Sciences,...
# 1    Agriculture & Food Sciences, Humanities & Arts...
# 2        Medicine & Health, Social Sciences & Behavior
# 3                                 Science & Technology
# 4                                    Medicine & Health
# ..                                                 ...
# 220                         Social Sciences & Behavior
# 221                                  Medicine & Health
# 222                                  Medicine & Health
# 223                               Science & Technology
# 224                                  Humanities & Arts
#
#                Opportunity Timing         Deadline Date  \
# 0                          Summer   Anticipated 12/8/24
# 1                          Summer              12/15/24
# 2                          Summer  Anticipated 12/31/24
# 3                          Summer              12/15/24
# 4                          Summer  Anticipated 12/17/24
# ..                            ...                   ...
# 220                  Fall, Summer   Anticipated 12/1/25
# 221                        Summer               Rolling
# 222                        Summer   Anticipated 1/31/26
# 223                        Spring               Rolling
# 224  Fall, Spring, Summer, Winter               Rolling
#
#                                 Sponsoring Institution          Location  \
# 0                   North Central Region Water Network           Various
# 1    Cornell University, Princeton University, Notr...    Nanyuki, Kenya
# 2                            University of Pensylvania  Philadelphia, PA
# 3    Virginia Polytechnic Institute and State Unive...  Grenoble, France
# 4                               University of Michigan     Ann Arbor, MI
# ..                                                 ...               ...
# 220            Congressional Hispanic Caucus Institute    Washington, DC
# 221                            Northwestern University      Evanston, IL
# 222                                 Cornell University        Ithaca, NY
# 223         University of Illinois at Urbana-Champaign        Urbana, IL
# 224                  Medieval and Early Modern Orients            Remote
#
#      Duration Compensation                            Citizenship Requirement
# 0    10 weeks    > $10,000  US Citizen, National, or Permanent Resident re...
# 1     7 weeks          NaN  US Citizen, National, or Permanent Resident re...
# 2    10 weeks       $6,000  US Citizen, National, or Permanent Resident re...
# 3     8 weeks       $4,400  US Citizen, National, or Permanent Resident re...
# 4    10 weeks       $5,700                        No Citizenship Requirements
# ..        ...          ...                                                ...
# 220  10 weeks       $3,125  US Citizen, National, or Permanent Resident re...
# 221  12 weeks       $3,400  US Citizen, National, or Permanent Resident re...
# 222  10 weeks       $7,000  US Citizen, National, or Permanent Resident re...
# 223  10 weeks          NaN                        No Citizenship Requirements
# 224   8 weeks          NaN                        No Citizenship Requirements
#
# [225 rows x 11 columns]
